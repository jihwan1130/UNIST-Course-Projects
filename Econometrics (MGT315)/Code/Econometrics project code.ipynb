# %%
# !pip install pandas

# %%
!--upgrade pippip install numpy
# Out:
# '--upgrade'��(��) ���� �Ǵ� �ܺ� ����, ������ �� �ִ� ���α׷�, �Ǵ�
# ��ġ ������ �ƴմϴ�.

# %%
import numpy as np
import pandas as pd
# import seaborn as sns
import statsmodels.api as sm
# import matplotlib as mpl
# import matplotlib.pyplot as plt

# %%
# import pandas as pd
# import numpy as np
# import seaborn as sns
# import statsmodels.api as sm
# import matplotlib as mpl
# import matplotlib.pyplot as plt

# %%
df = pd.read_excel('./teen_employ.xlsx')
df
# Out:
#       year  state    workft    workpt  employed  emp_rest  emp_rest_pt  \
# 0     1990      1  0.132765  0.208400  0.341165  0.120739     0.069231
# 1     1991      1  0.101886  0.219785  0.321671  0.076708     0.060223
# 2     1992      1  0.103357  0.206009  0.309366  0.091669     0.062027
# 3     1993      1  0.075959  0.267004  0.342963  0.078949     0.062745
# 4     1994      1  0.103731  0.172641  0.276372  0.110523     0.051927
# ...    ...    ...       ...       ...       ...       ...          ...
# 1219  2009     56  0.088409  0.289408  0.377816  0.096694     0.086597
# 1220  2010     56  0.059400  0.221699  0.281099  0.109372     0.098681
# 1221  2011     56  0.123639  0.234226  0.357866  0.059944     0.051051
# 1222  2012     56  0.116975  0.238533  0.355508  0.080796     0.065445
# 1223  2013     56  0.124309  0.272269  0.396578  0.160544     0.121253
#
#       emp_rest_ft  emp_retail  emp_retail_ft  ...  workftmin  workptmin  \
# ...

# %% [markdown]
# # Pooled OLS

# %%
df_11 = df[["year", 'state','employed', 'emp_retail', 'emp_retail_ft', 'emp_retail_pt', 'emp_rest', 'emp_rest_ft', 'emp_rest_pt',  'inschool', 'workft', 'workpt', 'minwage', 'cpi'
             , 'employed1617', 'employed1819', 'employedm', 'employedf', 'employedw', 'employedmin'  ]]
df_11['real_minwage'] =df_11["minwage"]/df_11['cpi'] *100
df_11
# Out:
# C:\Users\82106\AppData\Local\Temp\ipykernel_81964\2244917393.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   emp_df['real_minwage'] =emp_df["minwage"]/emp_df['cpi'] *100
#       year  state  employed  emp_retail  emp_retail_ft  emp_retail_pt  \
# 0     1990      1  0.341165    0.184516       0.078681       0.105836
# 1     1991      1  0.321671    0.152656       0.036284       0.116373
# 2     1992      1  0.309366    0.179134       0.046905       0.132229
# 3     1993      1  0.342963    0.170524       0.024870       0.145654
# 4     1994      1  0.276372    0.166627       0.074707       0.091919
# ...    ...    ...       ...         ...            ...            ...
# ...

# %%
df_11.describe()
# Out:
#               year        state     employed   emp_retail  emp_retail_ft  \
# count  1224.000000  1224.000000  1224.000000  1224.000000    1224.000000
# mean   2001.500000    28.960784     0.364974     0.193886       0.048172
# std       6.925016    15.683243     0.101115     0.056853       0.022750
# min    1990.000000     1.000000     0.049119     0.025638       0.000000
# 25%    1995.750000    16.000000     0.296215     0.155685       0.031545
# 50%    2001.500000    29.000000     0.365276     0.191442       0.045964
# 75%    2007.250000    42.000000     0.432068     0.231584       0.062109
# max    2013.000000    56.000000     0.680327     0.380729       0.143763
#
#        emp_retail_pt     emp_rest  emp_rest_ft  emp_rest_pt     inschool  ...  \
# count    1224.000000  1224.000000  1224.000000  1224.000000  1224.000000  ...
# mean        0.145714     0.097987     0.023345     0.074642     0.808755  ...
# ...

# %%
pip install linearmodels
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from linearmodels import PanelOLS

# %%
df_11['time'] = df_11['year']-1990
df_11
# Out:
# C:\Users\82106\AppData\Local\Temp\ipykernel_81964\4053195401.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   emp_df['time'] = emp_df['year']-1990
#       year  state  employed  emp_retail  emp_retail_ft  emp_retail_pt  \
# 0     1990      1  0.341165    0.184516       0.078681       0.105836
# 1     1991      1  0.321671    0.152656       0.036284       0.116373
# 2     1992      1  0.309366    0.179134       0.046905       0.132229
# 3     1993      1  0.342963    0.170524       0.024870       0.145654
# 4     1994      1  0.276372    0.166627       0.074707       0.091919
# ...    ...    ...       ...         ...            ...            ...
# 1219  2009     56  0.377816    0.172178       0.034890       0.137288
# ...

# %%
panel_df = df_11.set_index(['state', 'year'])
panel_df
# Out:
#             employed  emp_retail  emp_retail_ft  emp_retail_pt  emp_rest  \
# state year
# 1     1990  0.341165    0.184516       0.078681       0.105836  0.120739
#       1991  0.321671    0.152656       0.036284       0.116373  0.076708
#       1992  0.309366    0.179134       0.046905       0.132229  0.091669
#       1993  0.342963    0.170524       0.024870       0.145654  0.078949
#       1994  0.276372    0.166627       0.074707       0.091919  0.110523
# ...              ...         ...            ...            ...       ...
# 56    2009  0.377816    0.172178       0.034890       0.137288  0.096694
#       2010  0.281099    0.164353       0.035324       0.129029  0.109372
#       2011  0.357866    0.174633       0.066805       0.107828  0.059944
#       2012  0.355508    0.164961       0.054718       0.110243  0.080796
#       2013  0.396578    0.238489       0.078379       0.160110  0.160544
#
#             emp_rest_ft  emp_rest_pt  inschool    workft    workpt  minwage  \
# ...

# %%
new_panel_df = panel_df.copy()
new_panel_df
# Out:
#             employed  emp_retail  emp_retail_ft  emp_retail_pt  emp_rest  \
# state year
# 1     1990  0.341165    0.184516       0.078681       0.105836  0.120739
#       1991  0.321671    0.152656       0.036284       0.116373  0.076708
#       1992  0.309366    0.179134       0.046905       0.132229  0.091669
#       1993  0.342963    0.170524       0.024870       0.145654  0.078949
#       1994  0.276372    0.166627       0.074707       0.091919  0.110523
# ...              ...         ...            ...            ...       ...
# 56    2009  0.377816    0.172178       0.034890       0.137288  0.096694
#       2010  0.281099    0.164353       0.035324       0.129029  0.109372
#       2011  0.357866    0.174633       0.066805       0.107828  0.059944
#       2012  0.355508    0.164961       0.054718       0.110243  0.080796
#       2013  0.396578    0.238489       0.078379       0.160110  0.160544
#
#             emp_rest_ft  emp_rest_pt  inschool    workft    workpt  minwage  \
# ...

# %%
from linearmodels.panel import generate_panel_data

# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm
import statsmodels.formula.api as smf
import matplotlib.pyplot as plt
import linearmodels
from statsmodels.sandbox.regression.predstd import wls_prediction_std

# %%
import numpy as np
from scipy.stats import norm, gaussian_kde
import matplotlib.pyplot as plt
import pandas as pd
from linearmodels.panel.data import PanelData
from linearmodels.panel import PanelOLS, PooledOLS, RandomEffects, compare
from collections import OrderedDict
from statsmodels.formula.api import ols

# %%
from linearmodels.panel import generate_panel_data
model = PanelOLS.from_formula('employed ~ real_minwage  + EntityEffects', new_panel_df)
model2 =model.fit(cov_type = "clustered", cluster_entity=True)
print(model2)
# Out:
#                           PanelOLS Estimation Summary
# ...
# Dep. Variable:               employed   R-squared:                        0.1676
# Estimator:                   PanelOLS   R-squared (Between):             -3.0268
# No. Observations:                1224   R-squared (Within):               0.1676
# Date:                Mon, Jun 20 2022   R-squared (Overall):             -2.9099
# Time:                        05:38:48   Log-likelihood                    1588.4
# Cov. Estimator:             Clustered
#                                         F-statistic:                      235.96
# Entities:                          51   P-value                           0.0000
# Avg Obs:                       24.000   Distribution:                  F(1,1172)
# Min Obs:                       24.000
# Max Obs:                       24.000   F-statistic (robust):             218.15
#                                         P-value                           0.0000
# ...

# %%
model = PanelOLS.from_formula('employed ~ log(real_minwage) + TimeEffects+ EntityEffects', new_panel_df )
model2 =model.fit(cov_type = "clustered", cluster_entity=True)
print(model2)
# Out:
#                           PanelOLS Estimation Summary
# ...
# Dep. Variable:               employed   R-squared:                        0.0055
# Estimator:                   PanelOLS   R-squared (Between):             -0.4211
# No. Observations:                1224   R-squared (Within):               0.0514
# Date:                Mon, Jun 20 2022   R-squared (Overall):             -0.4038
# Time:                        05:38:52   Log-likelihood                    2027.1
# Cov. Estimator:             Clustered
#                                         F-statistic:                      6.4098
# Entities:                          51   P-value                           0.0115
# Avg Obs:                       24.000   Distribution:                  F(1,1149)
# Min Obs:                       24.000
# Max Obs:                       24.000   F-statistic (robust):             3.8730
#                                         P-value                           0.0493
# ...

# %%
########################################### employed
model = PanelOLS.from_formula('employed ~ log(real_minwage) + workpt + TimeEffects + EntityEffects', new_panel_df )
model2 =model.fit(cov_type = "clustered", cluster_entity=True)
print(model2)
# Out:
#                           PanelOLS Estimation Summary
# ...
# Dep. Variable:               employed   R-squared:                        0.5895
# Estimator:                   PanelOLS   R-squared (Between):              0.7248
# No. Observations:                1224   R-squared (Within):               0.7242
# Date:                Mon, Jun 20 2022   R-squared (Overall):              0.7248
# Time:                        05:38:55   Log-likelihood                    2568.6
# Cov. Estimator:             Clustered
#                                         F-statistic:                      824.26
# Entities:                          51   P-value                           0.0000
# Avg Obs:                       24.000   Distribution:                  F(2,1148)
# Min Obs:                       24.000
# Max Obs:                       24.000   F-statistic (robust):             843.29
#                                         P-value                           0.0000
# ...

# %%
#emp_retail
model = PanelOLS.from_formula('emp_retail ~ log(real_minwage) + workpt + TimeEffects + EntityEffects', new_panel_df )
model2 =model1.fit(cov_type = "clustered", cluster_entity=True)
print(model2)
# Out:
#                           PanelOLS Estimation Summary
# ...
# Dep. Variable:             emp_retail   R-squared:                        0.3727
# Estimator:                   PanelOLS   R-squared (Between):              0.8713
# No. Observations:                1224   R-squared (Within):               0.5408
# Date:                Mon, Jun 20 2022   R-squared (Overall):              0.8564
# Time:                        05:31:19   Log-likelihood                    2624.1
# Cov. Estimator:             Clustered
#                                         F-statistic:                      341.10
# Entities:                          51   P-value                           0.0000
# Avg Obs:                       24.000   Distribution:                  F(2,1148)
# Min Obs:                       24.000
# Max Obs:                       24.000   F-statistic (robust):             387.31
#                                         P-value                           0.0000
# ...

# %%
#emp_rest
model = PanelOLS.from_formula('emp_rest ~ log(real_minwage) + workpt + TimeEffects + EntityEffects', new_panel_df )
model2 =model1.fit(cov_type = "clustered", cluster_entity=True)
print(model2)
# Out:
#                           PanelOLS Estimation Summary
# ...
# Dep. Variable:               emp_rest   R-squared:                        0.1425
# Estimator:                   PanelOLS   R-squared (Between):              0.7249
# No. Observations:                1224   R-squared (Within):               0.1613
# Date:                Mon, Jun 20 2022   R-squared (Overall):              0.6855
# Time:                        05:31:50   Log-likelihood                    2817.6
# Cov. Estimator:             Clustered
#                                         F-statistic:                      95.400
# Entities:                          51   P-value                           0.0000
# Avg Obs:                       24.000   Distribution:                  F(2,1148)
# Min Obs:                       24.000
# Max Obs:                       24.000   F-statistic (robust):             98.770
#                                         P-value                           0.0000
# ...

# %%
#employed_1617
model = PanelOLS.from_formula('employed1617 ~ log(real_minwage) + workpt + TimeEffects + EntityEffects', new_panel_df )
model2 =model.fit(cov_type = "clustered", cluster_entity=True)
print(model2)
# Out:
#                           PanelOLS Estimation Summary
# ...
# Dep. Variable:           employed1617   R-squared:                        0.4688
# Estimator:                   PanelOLS   R-squared (Between):              0.8988
# No. Observations:                1224   R-squared (Within):               0.6591
# Date:                Mon, Jun 20 2022   R-squared (Overall):              0.8805
# Time:                        05:39:35   Log-likelihood                    2153.7
# Cov. Estimator:             Clustered
#                                         F-statistic:                      506.59
# Entities:                          51   P-value                           0.0000
# Avg Obs:                       24.000   Distribution:                  F(2,1148)
# Min Obs:                       24.000
# Max Obs:                       24.000   F-statistic (robust):             271.46
#                                         P-value                           0.0000
# ...

# %%
#employed_1819
model = PanelOLS.from_formula('employed1819 ~ log(real_minwage) + workpt + TimeEffects + EntityEffects', new_panel_df )
model2 =model.fit(cov_type = "clustered", cluster_entity=True)
print(model2)
# Out:
#                           PanelOLS Estimation Summary
# ...
# Dep. Variable:           employed1819   R-squared:                        0.2157
# Estimator:                   PanelOLS   R-squared (Between):              0.5454
# No. Observations:                1224   R-squared (Within):               0.4277
# Date:                Mon, Jun 20 2022   R-squared (Overall):              0.5418
# Time:                        05:40:07   Log-likelihood                    1756.2
# Cov. Estimator:             Clustered
#                                         F-statistic:                      157.87
# Entities:                          51   P-value                           0.0000
# Avg Obs:                       24.000   Distribution:                  F(2,1148)
# Min Obs:                       24.000
# Max Obs:                       24.000   F-statistic (robust):             108.04
#                                         P-value                           0.0000
# ...

# %%
#employed male
mode1 = PanelOLS.from_formula('employedm ~ log(real_minwage) + workpt + TimeEffects + EntityEffects', new_panel_df )
model2 =model.fit(cov_type = "clustered", cluster_entity=True)
print(model2)
# Out:
#                           PanelOLS Estimation Summary
# ...
# Dep. Variable:              employedm   R-squared:                        0.3240
# Estimator:                   PanelOLS   R-squared (Between):              0.7697
# No. Observations:                1224   R-squared (Within):               0.5399
# Date:                Mon, Jun 20 2022   R-squared (Overall):              0.7574
# Time:                        05:41:09   Log-likelihood                    1913.5
# Cov. Estimator:             Clustered
#                                         F-statistic:                      275.14
# Entities:                          51   P-value                           0.0000
# Avg Obs:                       24.000   Distribution:                  F(2,1148)
# Min Obs:                       24.000
# Max Obs:                       24.000   F-statistic (robust):             334.39
#                                         P-value                           0.0000
# ...

# %%
#employed female
model = PanelOLS.from_formula('employedf ~ log(real_minwage) + workpt + TimeEffects + EntityEffects', new_panel_df )
model2 = model.fit(cov_type = "clustered", cluster_entity=True)
print(model2)
# Out:
#                           PanelOLS Estimation Summary
# ...
# Dep. Variable:              employedf   R-squared:                        0.3500
# Estimator:                   PanelOLS   R-squared (Between):              0.6895
# No. Observations:                1224   R-squared (Within):               0.5582
# Date:                Mon, Jun 20 2022   R-squared (Overall):              0.6841
# Time:                        05:41:21   Log-likelihood                    1963.7
# Cov. Estimator:             Clustered
#                                         F-statistic:                      309.07
# Entities:                          51   P-value                           0.0000
# Avg Obs:                       24.000   Distribution:                  F(2,1148)
# Min Obs:                       24.000
# Max Obs:                       24.000   F-statistic (robust):             302.80
#                                         P-value                           0.0000
# ...

# %%
#employed white
model = PanelOLS.from_formula('employedw ~ log(real_minwage) + workpt + TimeEffects + EntityEffects', new_panel_df )
model2 =model.fit(cov_type = "clustered", cluster_entity=True)
print(model2)
# Out:
#                           PanelOLS Estimation Summary
# ...
# Dep. Variable:              employedw   R-squared:                        0.4250
# Estimator:                   PanelOLS   R-squared (Between):              0.7850
# No. Observations:                1224   R-squared (Within):               0.6205
# Date:                Mon, Jun 20 2022   R-squared (Overall):              0.7781
# Time:                        05:41:51   Log-likelihood                    2056.7
# Cov. Estimator:             Clustered
#                                         F-statistic:                      424.27
# Entities:                          51   P-value                           0.0000
# Avg Obs:                       24.000   Distribution:                  F(2,1148)
# Min Obs:                       24.000
# Max Obs:                       24.000   F-statistic (robust):             552.75
#                                         P-value                           0.0000
# ...

# %%
#employed minorities
model = PanelOLS.from_formula('employedmin ~ log(real_minwage) + workpt + TimeEffects + EntityEffects', new_panel_df )
model2 =model.fit(cov_type = "clustered", cluster_entity=True)
print(model2)
# Out:
#                           PanelOLS Estimation Summary
# ...
# Dep. Variable:            employedmin   R-squared:                        0.0568
# Estimator:                   PanelOLS   R-squared (Between):              0.2129
# No. Observations:                1218   R-squared (Within):               0.1293
# Date:                Mon, Jun 20 2022   R-squared (Overall):              0.2015
# Time:                        05:42:12   Log-likelihood                    1136.2
# Cov. Estimator:             Clustered
#                                         F-statistic:                      34.369
# Entities:                          51   P-value                           0.0000
# Avg Obs:                       23.882   Distribution:                  F(2,1142)
# Min Obs:                       20.000
# Max Obs:                       24.000   F-statistic (robust):             24.979
#                                         P-value                           0.0000
# ...

# %%
model = PanelOLS.from_formula('inschool ~ log(real_minwage) + workpt + TimeEffects + EntityEffects', new_panel_df )
model2 = model.fit(cov_type = "clustered", cluster_entity=True)
print(model2)

# %%
model1 = PanelOLS.from_formula('employed ~ log(real_minwage) +inschool+ EntityEffects', new_panel_df )
model2 =model.fit(cov_type = "clustered", cluster_entity=True)
print(model2)
# Out:
#                           PanelOLS Estimation Summary
# ...
# Dep. Variable:               employed   R-squared:                        0.3072
# Estimator:                   PanelOLS   R-squared (Between):             -9.1740
# No. Observations:                1224   R-squared (Within):               0.3072
# Date:                Mon, Jun 20 2022   R-squared (Overall):             -8.8270
# Time:                        02:33:02   Log-likelihood                    1700.7
# Cov. Estimator:             Clustered
#                                         F-statistic:                      259.56
# Entities:                          51   P-value                           0.0000
# Avg Obs:                       24.000   Distribution:                  F(2,1171)
# Min Obs:                       24.000
# Max Obs:                       24.000   F-statistic (robust):             216.89
#                                         P-value                           0.0000
# ...

# %%
model = PanelOLS.from_formula('employed ~ log(real_minwage) +workpt+ inschool+ EntityEffects', new_panel_df )
model2 = model1.fit(cov_type = "clustered", cluster_entity=True)
print(model2)
# Out:
#                           PanelOLS Estimation Summary
# ...
# Dep. Variable:               employed   R-squared:                        0.8423
# Estimator:                   PanelOLS   R-squared (Between):             -1.0282
# No. Observations:                1224   R-squared (Within):               0.8423
# Date:                Mon, Jun 20 2022   R-squared (Overall):             -0.9598
# Time:                        02:33:10   Log-likelihood                    2606.7
# Cov. Estimator:             Clustered
#                                         F-statistic:                      2083.6
# Entities:                          51   P-value                           0.0000
# Avg Obs:                       24.000   Distribution:                  F(3,1170)
# Min Obs:                       24.000
# Max Obs:                       24.000   F-statistic (robust):             1646.1
#                                         P-value                           0.0000
# ...

# %%
model = PanelOLS.from_formula('workft ~ log(real_minwage) + inschool+ EntityEffects', new_panel_df )
model2 =model.fit(cov_type = "clustered", cluster_entity=True)
print(model2)
# Out:
#                           PanelOLS Estimation Summary
# ...
# Dep. Variable:                 workft   R-squared:                        0.3960
# Estimator:                   PanelOLS   R-squared (Between):             -24.976
# No. Observations:                1224   R-squared (Within):               0.3960
# Date:                Mon, Jun 20 2022   R-squared (Overall):             -22.502
# Time:                        07:44:18   Log-likelihood                    2594.6
# Cov. Estimator:             Clustered
#                                         F-statistic:                      383.83
# Entities:                          51   P-value                           0.0000
# Avg Obs:                       24.000   Distribution:                  F(2,1171)
# Min Obs:                       24.000
# Max Obs:                       24.000   F-statistic (robust):             211.01
#                                         P-value                           0.0000
# ...
